# %% [markdown]
# **Importar librerias**

# %%
import pandas as pd

# %% [markdown]
# # Cargar csv

# %%
df_agosto = pd.read_csv('./DatasetsRutas/rutas_trabajo_agosto.csv', header = 0)

# %% [markdown]
# ###  El dataset tiene 165 columnas, pero son los mismos valores para ciudades distintas, porlo que quizas se pueda hacer una agrupación

# %%
df_agosto.head()
# Out:
#    Semana        Día       Fecha  Cliente     Localidad        Lat       Lon  \
# 0       1     Friday  01/08/2025      3.0  Sto. Domingo  42.433120 -2.950750
# 1       2     Monday  04/08/2025      9.0       Logroño  42.450132 -2.447887
# 2       2    Tuesday  05/08/2025     32.0       Vitoria  42.838500 -2.709793
# 3       2    Tuesday  05/08/2025     39.0          Haro  42.568106 -2.858153
# 4       2  Wednesday  06/08/2025     31.0     Agoncillo  42.449634 -2.294349
#
#    Horas  Tiempo_Desplazamiento_min
# 0    6.0                      46.06
# 1    6.0                      65.76
# 2    3.0                      85.95
# 3    3.0                      85.95
# 4    3.0                     153.82

# %%
df_septiembre = pd.read_csv('./DatasetsRutas/rutas_trabajo_septiembre.csv', header = 0)

# %%
df_septiembre.head()
# Out:
#    Semana        Día       Fecha  Cliente   Localidad        Lat       Lon  \
# 0       1     Monday  01/09/2025     28.0    Cenicero  42.487053 -2.632611
# 1       1    Tuesday  02/09/2025     25.0  El Rasillo  42.194761 -2.701588
# 2       1  Wednesday  03/09/2025     26.0       Nieva  42.219015 -2.666988
# 3       1   Thursday  04/09/2025     30.0     Logroño  42.450132 -2.447887
# 4       1     Friday  05/09/2025     29.0   Laguardia  42.546423 -2.576605
#
#    Horas  Tiempo_Desplazamiento_min
# 0    5.5                      37.50
# 1    5.5                     125.35
# 2    5.5                     117.13
# 3    5.5                      65.76
# 4    4.0                      62.79

# %%
df_octubre = pd.read_csv('./DatasetsRutas/rutas_trabajo_octubre.csv', header = 0)

# %%
df_octubre.head()
# Out:
#    Semana        Día       Fecha  Cliente  Localidad        Lat       Lon  \
# 0       1  Wednesday  01/10/2025     32.0    Vitoria  42.838500 -2.709793
# 1       1   Thursday  02/10/2025     39.0       Haro  42.568106 -2.858153
# 2       1     Friday  03/10/2025     31.0  Agoncillo  42.449634 -2.294349
# 3       2     Monday  06/10/2025     40.0    Vitoria  42.838500 -2.709793
# 4       2     Monday  06/10/2025     28.0   Cenicero  42.487053 -2.632611
#
#    Horas  Tiempo_Desplazamiento_min
# 0   5.00                      77.75
# 1   5.00                      15.67
# 2   5.00                      81.77
# 3   3.00                     109.70
# 4   2.25                     109.70

# %%
df_noviembre = pd.read_csv('./DatasetsRutas/rutas_trabajo_noviembre.csv', header = 0)

# %%
df_noviembre.head()
# Out:
#    Semana        Día       Fecha  Cliente   Localidad        Lat       Lon  \
# 0       2     Monday  03/11/2025     39.0        Haro  42.568106 -2.858153
# 1       2     Monday  03/11/2025     32.0     Vitoria  42.838500 -2.709793
# 2       2    Tuesday  04/11/2025     31.0   Agoncillo  42.449634 -2.294349
# 3       2    Tuesday  04/11/2025     30.0     Logroño  42.450132 -2.447887
# 4       2  Wednesday  05/11/2025     25.0  El Rasillo  42.194761 -2.701588
#
#    Horas  Tiempo_Desplazamiento_min
# 0   3.00                      86.16
# 1   3.00                      86.16
# 2   3.00                      91.83
# 3   2.25                      91.83
# 4   2.25                     134.82

# %%
df_diciembre = pd.read_csv('./DatasetsRutas/rutas_trabajo_diciembre.csv', header = 0)

# %%
df_diciembre.head()
# Out:
#    Semana        Día       Fecha  Cliente  Localidad        Lat       Lon  \
# 0       1     Monday  01/12/2025     44.0      Sesma  42.475966 -2.084940
# 1       1    Tuesday  02/12/2025     50.0  Fuenmayor  42.467631 -2.555735
# 2       1  Wednesday  03/12/2025     49.0   Cenicero  42.487053 -2.632611
# 3       1   Thursday  04/12/2025     48.0      Araia  42.886863 -2.313917
# 4       1     Friday  05/12/2025     46.0  Los Arcos  42.573983 -2.193257
#
#    Horas  Tiempo_Desplazamiento_min
# 0    4.0                     120.91
# 1    4.0                      46.80
# 2    4.0                      37.50
# 3    4.0                     112.41
# 4    4.0                     102.23

# %%
# Lista de tus DataFrames
dataframes = [df_agosto, df_septiembre, df_octubre, df_noviembre, df_diciembre]

# Concatenar todos en uno solo
df_concatenado = pd.concat(dataframes, ignore_index=True)

# %%
df_concatenado
# Out:
#      Semana        Día       Fecha  Cliente     Localidad        Lat  \
# 0         1     Friday  01/08/2025      3.0  Sto. Domingo  42.433120
# 1         2     Monday  04/08/2025      9.0       Logroño  42.450132
# 2         2    Tuesday  05/08/2025     32.0       Vitoria  42.838500
# 3         2    Tuesday  05/08/2025     39.0          Haro  42.568106
# 4         2  Wednesday  06/08/2025     31.0     Agoncillo  42.449634
# ..      ...        ...         ...      ...           ...        ...
# 142       3    Tuesday  16/12/2025     26.0         Nieva  42.219015
# 143       3  Wednesday  17/12/2025     29.0     Laguardia  42.546423
# 144       3  Wednesday  17/12/2025      4.0        Durana  42.887026
# 145       3  Wednesday  17/12/2025      5.0          Haro  42.568106
# 146       3  Wednesday  17/12/2025      1.0          Haro  42.568106
#
#           Lon  Horas  Tiempo_Desplazamiento_min
# 0   -2.950750   6.00                      46.06
# ...

# %%
df_concatenado.to_csv("DatasetsRutas/archivo_concatenado.csv", index=False)
